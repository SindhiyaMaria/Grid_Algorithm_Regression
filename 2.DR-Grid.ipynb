# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age','bmi','children','sex_male','smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(independent, dependent ,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['mse','mae','friedman_mse'],
            'max_features':['auto','sqrt','log2'],'splitter':['best', 'random']}


grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
   
# fitting the model for grid search 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae', 'friedman_mse'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(x_test)

# print classification report 
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions) 
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'mse', 'max_features': 'auto', 'splitter': 'best'}: 0.7036188303389294

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002591  7.972598e-04         0.000000        0.000000
# 1        0.018044  3.210754e-02         0.000000        0.000000
# 2        0.001595  4.882468e-04         0.000000        0.000000
# 3        0.002192  9.764643e-04         0.000000        0.000000
# 4        0.002393  4.890453e-04         0.000000        0.000000
# 5        0.001993  1.168008e-07         0.000000        0.000000
# 6        0.015348  9.126277e-03         0.001395        0.000488
# 7        0.003388  4.885395e-04         0.002193        0.001933
# 8        0.003292  8.728307e-04         0.001395        0.000488
# 9        0.003188  3.998589e-04         0.001195        0.000398
# 10       0.003796  1.177942e-03         0.001057        0.000120
# 11       0.002483  6.174832e-04         0.001994        0.001261
# 12       0.002393  1.018049e-03         0.000000        0.000000
# 13       0.002191  3.990464e-04         0.000000        0.000000
# 14       0.001794  7.454609e-04         0.000000        0.000000
# 15       0.001594  4.888319e-04         0.000000        0.000000
# 16       0.001995  2.565189e-06         0.000000        0.000000
# 17       0.002990  1.260220e-03         0.000000        0.000000
# 18       0.035789  2.468695e-02         0.004386        0.001016
# 19       0.009170  3.981413e-04         0.003389        0.001016
# 20       0.013355  5.370954e-03         0.003690        0.001075
# 21       0.008571  4.882856e-04         0.003788        0.000746
# 22       0.009503  1.967970e-03         0.007478        0.008266
# 23       0.008371  7.989532e-04         0.003527        0.001292
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               auto           best
# 1    squared_error               auto         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               auto           best
# 7     friedman_mse               auto         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               auto           best
# 13  absolute_error               auto         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               auto           best
# 19         poisson               auto         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...                NaN
# 3   {'criterion': 'squared_error', 'max_features':...                NaN
# 4   {'criterion': 'squared_error', 'max_features':...                NaN
# 5   {'criterion': 'squared_error', 'max_features':...                NaN
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.726767
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.722203
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.404207
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.505646
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.783272
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.668593
# 12  {'criterion': 'absolute_error', 'max_features'...                NaN
# 13  {'criterion': 'absolute_error', 'max_features'...                NaN
# 14  {'criterion': 'absolute_error', 'max_features'...                NaN
# 15  {'criterion': 'absolute_error', 'max_features'...                NaN
# 16  {'criterion': 'absolute_error', 'max_features'...                NaN
# 17  {'criterion': 'absolute_error', 'max_features'...                NaN
# 18  {'criterion': 'poisson', 'max_features': 'auto...           0.706383
# 19  {'criterion': 'poisson', 'max_features': 'auto...           0.618185
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.657820
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.674616
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.695820
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.601495
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
# 5                 NaN                NaN                NaN
# 6            0.540888           0.780131           0.646297
# 7            0.712521           0.616012           0.635691
# 8            0.323499           0.596759           0.676793
# 9            0.608223           0.571487           0.557958
# 10           0.608208           0.694521           0.458010
# 11           0.561264           0.698508           0.504014
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18           0.553551           0.640865           0.672942
# 19           0.422783           0.630875           0.568465
# 20           0.538874           0.595367           0.601558
# 21           0.543277           0.569510           0.519577
# 22           0.505402           0.515875           0.497823
# 23           0.607550           0.495880           0.452994
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               24
# 1                 NaN              NaN             NaN               23
# 2                 NaN              NaN             NaN               22
# 3                 NaN              NaN             NaN               21
# 4                 NaN              NaN             NaN               14
# 5                 NaN              NaN             NaN               13
# 6            0.650966         0.669010        0.081167                1
# 7            0.608917         0.659069        0.048495                2
# 8            0.589847         0.518221        0.132181               12
# 9            0.630721         0.574807        0.043177                9
# 10           0.679993         0.644801        0.108733                4
# 11           0.641361         0.614748        0.071758                5
# 12                NaN              NaN             NaN               15
# 13                NaN              NaN             NaN               16
# 14                NaN              NaN             NaN               17
# 15                NaN              NaN             NaN               18
# 16                NaN              NaN             NaN               19
# 17                NaN              NaN             NaN               20
# 18           0.657853         0.646319        0.051157                3
# 19           0.356954         0.519452        0.109832               11
# 20           0.517890         0.582302        0.049557                6
# 21           0.582863         0.577969        0.053008                7
# 22           0.665100         0.576004        0.086031                8
# 23           0.606171         0.552818        0.065450               10

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:61
# BMI:30
# Children:0
# Sex Male 0 or 1:0
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])# change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[63770.42801]
